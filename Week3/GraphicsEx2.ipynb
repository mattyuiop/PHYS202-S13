# %% [markdown]
# \begin{equation}
#  \psi _k (x) = A \Bigl( \frac{{ik - a \tanh(ax)}}{{ik + a}} \Bigr) e ^{+ikx}
# \end{equation}

# %% [markdown]
# $ v_1 = m_2 \sqrt { \frac{{2G}}{{M}} ( \frac{{1}}{{r}} - \frac{{1}}{{r_0}} ) } $

# %% [markdown]
# $ f( \theta ) = \frac {{\hbar}} {{p}} \displaystyle\sum_{ \mathscr{l} =0}^{\infty} (2l + 1)e^{i \delta _l} \sin \delta_l P_l (\cos \theta )$

# %% [markdown]
# $ \frac{d\sigma}{d\Omega} = \frac {k \pi ^2 ( \pi - \theta ) }{mu_{0}^{2} \theta^{2} ( 2 \pi - \theta ) ^2 \sin \theta } $

# %% [markdown]
# $ \langle f \rangle = \frac{1}{\tau} \displaystyle\int _0^\tau f(t) dt $

# %% [markdown]
# $\Omega _S = \omega \frac{\sin \alpha}{\sin \theta} = \frac{L}{ \lambda_1 } = \omega \frac{\sqrt{\lambda_3^2 + (\lambda_1^2 - \lambda_3^2 ) \sin \alpha }}{\lambda_1}$

# %% [markdown]
# Q2
# ------

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
x = np.arange(-pi, pi, .01)
y = -cosh(x)**(-2)
plot(x,y)
q,r,s,t = 0,0.5,1,2
psiq = (q**2 + tanh(x)**2)/(q**2 + 1)
plot(x,psiq, label="$\psi^2$, q = 0", color='r', linewidth=2.5)
psir = (r**2 + tanh(x)**2)/(r**2 + 1)
plot(x,psir, label="$\psi^2$, q = 0.5", color='r', linewidth=t, linestyle='--')
psis = (s**2 + tanh(x)**2)/(s**2 + 1)
plot(x,psis, label="$\psi^2$, q = 1", color='r', linewidth=s, linestyle='-.')
psit = (t**2 + tanh(x)**2)/(t**2 + 1)
plot(x,psit, label="$\psi^2$, q = 2",color='r', linewidth=r, linestyle=':')
legend(loc = 4)
grid(True)
#plt.xticks([-pi, -.5*pi, 0,.5*pi,pi],['-$\frac{\pi}{2}$', '$\pi$', '0', '$\frac{\pi}{2}$', '\pi'])

# %%
data = loadtxt("sunspots.txt",float)
x = data[:999,0]
y = data[:999,1]
xyr = linspace(1749,1749+1000/12,999)
avg = linspace(0,99,999)
n = 0
for i in y:
    avg[n] = ((n*mean(avg) + i)/(n+1))
    n+=1
    
plot(xyr,y, label="Sunspots Counts", color= 'm')
plot(xyr,avg, label="Running Avg Sunspots Counts", color= 'g', linewidth = 2.3, linestyle = '--')
xlabel('Year')
ylabel('Counts (sunspots)')
legend(loc = 'best')

# %%
data = loadtxt("stars.txt",float)
x = data[:,0]
y = data[:,1]
HR = plot(x,y,'o', linewidth = 2)
plt.gca().invert_xaxis()
plt.gca().invert_yaxis()
xlabel('$\longleftarrow $ increasing       Temperture (K)      decreasing $\longrightarrow$')
ylabel('Intensity (Luminosity)')

# %%
x.shape
# Out:
# (7860,)

# %%
num = range(7860)
rGnt=[]
wDwf=[]
main=[]
rGnty=[]
wDwfy=[]
mainy=[]
r,w,m = 0,0,0
for i in num:
    r1 = y[num]<=1
    r2 = x[num]>4000
    r3 = x[num]<6000
    ra = r1 & r2 & r3
    w1 = y[num] > 10
    w2 = x[num]> 4000
    wa = array([w1,w2])
    if ra.all():
        r +=1
    elif wa.all():
        w +=1
    else:
        m+=1
print r,w,m
# Out:
# 0 0 7860
# 0 0 7860

# %%
ra.all()
# Out:
# False

# %%
array([True, True, False]).all()
# Out:
# False
