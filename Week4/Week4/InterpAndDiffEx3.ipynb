# %%
from Electrostatics import *
x,y = meshgrid(arange(-5,5,0.55),arange(-5,5,0.55))
Vdipole = dipolePotential(x,y,1e-9, 1e-9,2)
contour(x,y,Vdipole,cmap=cm.summer)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x10a0de9e0>
