# %%
from Electrostatics import *

# %% [markdown]
# ##Ex. 1

# %%
from mpl_toolkits.mplot3d import Axes3D
x,y = meshgrid(arange(-0.05, 0.05, 0.0006), arange(-0.05, 0.05,0.0006))
V = pointPotential(x, y, -2e-9, 0., -0.0005) + dipolePotential(x, y, 3e-9,3e-9, 0.01)
fig = figure()
ax = fig.gca(projection='3d')
v = ax.plot_surface(x,y,V, rstride=1, cstride=1, cmap=cm.coolwarm, linewidth=0)

# %%
levels = array([8, 4, 2, 0.5, 0.25, 0, -0.25, -0.5, -1, -2, -4, -8])
levels = levels*10000
contour(x, y, V, levels, cmap= cm.coolwarm, linewidth=3)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x10cad92d8>

# %% [markdown]
# Using Boolean masks to find data
# --

# %%
theta=arange(0., 2*pi+0.1, pi/100)
plot(theta, sin(theta))
show()

# %%
mask = (sin(theta)>0) & (sin(theta)<0.5)
#print mask
plot(theta,sin(theta),theta[mask],sin(theta[mask]))
show()

# %%
y= sin(theta[mask])
jj= (y==max(y))
y[jj] = NaN #NaN is for not a number special way of saying infinity and gets rid of the the thing we set to NaN

# %%
plot(theta, sin(theta))
plot(theta[mask],y,linewidth=4)
show()

# %% [markdown]
# # Interpolation

# %%
theta = arange(0., 2*pi, pi/10)
mask = (theta == 0.5)
print mask
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False]

# %%
newTheta = 0.5; newSin = 0.
from scipy.interpolate import interp1d
#help(interp1d)
sinInterp = interp1d(theta, sin(theta)) #created inerpoltaing function
newSin = sinInterp(newTheta)
print newSin
# Out:
# 0.473922198704

# %%
plot(theta,sin(theta), newTheta,newSin, 'r+', markersize=20, markeredgewidth=3)
show()

# %%
thetaNew = arange(0.,2*pi+0.1,pi/30)
sinNew = interp1d(theta,sin(theta))(thetaNew) #same as what we did in last cell
plot(theta, sin(theta), thetaNew, sinNew, 'r.')
show()

# %%
plot(thetaNew, sinNew-sin(thetaNew))
ylabel('difference between interp and exact value')
show()

# %%
sinNewC = interp1d(theta, sin(theta), kind='cubic')(thetaNew)
subplot(2,1,1)
plot(thetaNew, sinNew-sin(thetaNew), thetaNew, sinNewC- sin(thetaNew), 'r')
subplot(2,1,2)
plot(thetaNew, sinNewC - sin(thetaNew), 'r')
show()
