# %% [markdown]
# #3D Plotting & Funkshon

# %% [markdown]
# #Electric Dipole Potential

# %% [markdown]
#  $V(x,y) = \frac{kq}{\sqrt{x^2+ (y-d)^2}} - \frac{kq}{\sqrt{x^2+ (y+d)^2}}$

# %%
#natual units
k,q,d = 1,1,1

# %%
import numpy as np
# mk xy grid cover [-2,2] x [-2,2]
dx = 0.06
dy = 0.06
x,y = meshgrid(arange(-2.,2.,dx),arange(-2.,2.,dy))
'''print x.ndim
print y.shape
print x
print y'''
# Out:
# 'print x.ndim\nprint y.shape\nprint x\nprint y'

# %%
Vxy = k*q/sqrt(x**2 + (y-d)**2) - k*q/sqrt(x**2 + (y+d)**2)

# %%
print Vxy
Vxy.shape
# Out:
# [[-0.1698635  -0.17826925 -0.18715865 ..., -0.19336737 -0.18414007
#   -0.17541494]
#  [-0.17127992 -0.17998007 -0.18920149 ..., -0.19565471 -0.18606779
#   -0.17702367]
#  [-0.17245961 -0.18144664 -0.19099347 ..., -0.19768747 -0.18774672
#   -0.17839056]
#  ...,
#  [ 0.17310174  0.18227437  0.19203282 ...,  0.19888408  0.18871243
#    0.17915368]
#  [ 0.17209427  0.1809867   0.19042599 ...,  0.19704029  0.18721662
#    0.1779635 ]
#  [ 0.17083282  0.17943553  0.18854686 ...,  0.19491887  0.18545135
#    0.17651294]]
# (67, 67)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection ='3d')
#p = ax.plot_surface(x,y,Vxy,rstride = 1, cstride=1,linewidth = 0, cmap=cm.coolwarm)

# %%
levels = array([8,4,2,1,0.5,0.25,0,-0.25, -0.5, -1,-2, -4,-8])
contour(x,y,Vxy,levels,cmap = cm.hot, linewidths = 5)
show()

# %%
x,y = meshgrid(arange(-6.,6.,13./51),arange(-6.,6.,13./51))

# %%
G = exp(-1*(x**2 + y**2))
fig = figure()
ax = fig.gca(projection ='3d')
p = ax.plot_surface(x,y,G,rstride = 1, cstride=1,linewidth = 0, cmap=cm.winter)
#sideShow = contour(x,y,G,array[

# %%
print Vxy
# Out:
# [[-0.1698635  -0.17826925 -0.18715865 ..., -0.19336737 -0.18414007
#   -0.17541494]
#  [-0.17127992 -0.17998007 -0.18920149 ..., -0.19565471 -0.18606779
#   -0.17702367]
#  [-0.17245961 -0.18144664 -0.19099347 ..., -0.19768747 -0.18774672
#   -0.17839056]
#  ...,
#  [ 0.17310174  0.18227437  0.19203282 ...,  0.19888408  0.18871243
#    0.17915368]
#  [ 0.17209427  0.1809867   0.19042599 ...,  0.19704029  0.18721662
#    0.1779635 ]
#  [ 0.17083282  0.17943553  0.18854686 ...,  0.19491887  0.18545135
#    0.17651294]]

# %%
def pointPotential(x,y,q,Xc,Yc):
        """Return electric potential for a point"""
        k = 8.9875511787e9
        Vxy = k*q/sqrt((x-Xc)**2 + (y-Yc)**2)
        return Vxy

def dipolePotential(x,y,q1,q2,d):
        """Return electric potential for a dipole on yaxis d units 
         from the origin"""
        k = 8.9875511787e9
        Vxy = k*q1/sqrt((x)**2 + (y-d)**2) + k*q2/sqrt((x)**2 + (y+d)**2)
        return Vxy
